# %% [markdown]
# Dataset taken from kaggle and is the tmdb dataset for 5000 movies

# %%
import numpy as np
import pandas as pd

# %%
movies=pd.read_csv('tmdb_5000_movies.csv')
credits=pd.read_csv('tmdb_5000_credits.csv')

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %% [markdown]
# budget - The budget in which the movie was made.
#
# genre - The genre of the movie, Action, Comedy ,Thriller etc.
#
# homepage - A link to the homepage of the movie.
#
# id - This is infact the movie_id as in the first dataset.
#
# keywords - The keywords or tags related to the movie.
# original_language - The language in which the movie was made.
#
# original_title - The title of the movie before translation or adaptation.
# overview - A brief description of the movie.
#
# popularity - A numeric quantity specifying the movie popularity.
#
#
# production_companies - The production house of the movie.
#
# production_countries - The country in which it was produced.
#
# release_date - The date on which it was released.
#
# revenue - The worldwide revenue generated by the movie.
#
# runtime - The running time of the movie in minutes.
#
# status - "Released" or "Rumored".
#
# tagline - Movie's tagline.
#
# title - Title of the movie.
#
# vote_average - average ratings the movie recieved.
#
# vote_count - the count of votes recieved.

# %%
credits.head(1)
# Out:
#    movie_id   title                                               cast  \
# 0     19995  Avatar  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %% [markdown]
# First step is to merge the two dataframes via the ID number or the title

# %%
#via id
credits=credits.rename(columns={'movie_id': 'id'})
combined_id=movies.merge(credits, on='id')

# %%
combined_id
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
combined_title=movies.merge(credits, on='title')

# %%
combined_title
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4804     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4805       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4806          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4807          0                                                 []
# 4808          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage    id_x  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# Handling unnecessary columns
#
# We need a content based system where we create tags. If budget is high wouldnt indictae users will like all high budget movies. Can be dropped.
#
# Homepage is uneccessary as well
#
# Language in this case is unecessary as well since the distribution of languages is almost 95% english.
#
# Original title is redudant so can be removed
#
# Popularity is a numeric measure and doesnt align with the approach of creating tags
#
# Production companies arent that useful as well
#
# Same with production countries
# Release date could be a factor (can be incorporated later), future work.
# revenue, runtime and spoken languages arent that relevant as well.
#
# Status, tagline arent that important
# voting counts also we wont, we are not recommending based on popularity

# %%
movies_final=combined_title[['id_x','title', 'overview', 'genres', 'keywords', 'cast', 'crew' ]]

# %%
movies_final
# Out:
#         id_x                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# ...

# %% [markdown]
# New data frame should have movie-id, title and tags (all information that will help identify the movie)
# For cast and crew we will consider the top 4 members. Rdeccomendation is done based on that

# %%
#missing data
movies_final.isnull().sum()
# Out:
# id_x        0
# title       0
# overview    3
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
movies_final.dropna(inplace=True)
# Out:
# <ipython-input-9-c6fd7b24be8d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_final.dropna(inplace=True)

# %%
movies_final.duplicated().sum()
# Out:
# 0

# %%
movies_final.iloc[0].genres
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
# [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]
#we need this finally '['action', 'adventure'...]
import ast #to convert a string into list
def convert(obj):
  l1=[]
  for i in ast.literal_eval(obj): #i is a dictionary, you cant fo obj directlt
    l1.append(i['name'])
  return l1

# %%
movies_final['genres']=movies_final['genres'].apply(convert)
# Out:
# <ipython-input-13-444fc66a4813>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_final['genres']=movies_final['genres'].apply(convert)

# %%
movies_final['genres'].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4804    False
# 4805    False
# 4806    False
# 4807    False
# 4808    False
# Name: genres, Length: 4806, dtype: bool

# %%
movies_final['keywords']=movies_final['keywords'].apply(convert)
# Out:
# <ipython-input-15-b33f4d47f0e0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_final['keywords']=movies_final['keywords'].apply(convert)

# %%
movies_final
# Out:
#         id_x                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# ...

# %%
#from every dictionary I want the top 4
import ast #to convert a string into list

def convert(obj):
  l1=[]
  counter=0
  for i in ast.literal_eval(obj): #i is a dictionary, you cant fo obj directlt
    if counter!=4: #original has top 3
      l1.append(i['name'])
      counter=counter+1
    else:
      break
  return l1

# %%
movies_final['cast']=movies_final['cast'].apply(convert)
# Out:
# <ipython-input-18-6863f92314b4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_final['cast']=movies_final['cast'].apply(convert)

# %%
movies_final['cast']
# Out:
# 0       [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 1       [Johnny Depp, Orlando Bloom, Keira Knightley, ...
# 2       [Daniel Craig, Christoph Waltz, Léa Seydoux, R...
# 3       [Christian Bale, Michael Caine, Gary Oldman, A...
# 4       [Taylor Kitsch, Lynn Collins, Samantha Morton,...
#                               ...
# 4804    [Carlos Gallardo, Jaime de Hoyos, Peter Marqua...
# 4805    [Edward Burns, Kerry Bishé, Marsha Dietlein, C...
# 4806    [Eric Mabius, Kristin Booth, Crystal Lowe, Geo...
# 4807    [Daniel Henney, Eliza Coupe, Bill Paxton, Alan...
# 4808    [Drew Barrymore, Brian Herzlinger, Corey Feldm...
# Name: cast, Length: 4806, dtype: object

# %%
movies_final['crew'][0]
# Out:
# '[{"credit_id": "52fe48009251416c750aca23", "department": "Editing", "gender": 0, "id": 1721, "job": "Editor", "name": "Stephen E. Rivkin"}, {"credit_id": "539c47ecc3a36810e3001f87", "department": "Art", "gender": 2, "id": 496, "job": "Production Design", "name": "Rick Carter"}, {"credit_id": "54491c89c3a3680fb4001cf7", "department": "Sound", "gender": 0, "id": 900, "job": "Sound Designer", "name": "Christopher Boyes"}, {"credit_id": "54491cb70e0a267480001bd0", "department": "Sound", "gender": 0, "id": 900, "job": "Supervising Sound Editor", "name": "Christopher Boyes"}, {"credit_id": "539c4a4cc3a36810c9002101", "department": "Production", "gender": 1, "id": 1262, "job": "Casting", "name": "Mali Finn"}, {"credit_id": "5544ee3b925141499f0008fc", "department": "Sound", "gender": 2, "id": 1729, "job": "Original Music Composer", "name": "James Horner"}, {"credit_id": "52fe48009251416c750ac9c3", "department": "Directing", "gender": 2, "id": 2710, "job": "Director", "name": "James Cameron"
# ...

# %%
#crew is a little difficult
#I only care about director only and maybe producer as well (extra)
def convert(obj):
  l1=[]
  counter=0
  for i in ast.literal_eval(obj): #i is a dictionary, you cant fo obj directlt

    if i['job']=='Director':
      l1.append(i['name'])
      break
  return l1

# %%
movies_final['crew']=movies_final['crew'].apply(convert)
# Out:
# <ipython-input-22-fba39e2eb910>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_final['crew']=movies_final['crew'].apply(convert)

# %%
movies_final['crew']
# Out:
# 0           [James Cameron]
# 1          [Gore Verbinski]
# 2              [Sam Mendes]
# 3       [Christopher Nolan]
# 4          [Andrew Stanton]
#                ...
# 4804     [Robert Rodriguez]
# 4805         [Edward Burns]
# 4806          [Scott Smith]
# 4807          [Daniel Hsia]
# 4808     [Brian Herzlinger]
# Name: crew, Length: 4806, dtype: object

# %%
movies_final['overview'][0]
# Out:
# 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.'

# %%
#we need to convert this to list as well so we can concatenta everything together
movies_final['overview']=movies_final['overview'].apply(lambda x:x.split())
# Out:
# <ipython-input-25-c64aa895d113>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_final['overview']=movies_final['overview'].apply(lambda x:x.split())

# %%
movies_final
# Out:
#         id_x                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                                overview  \
# 0     [In, the, 22nd, century,, a, paraplegic, Marin...
# 1     [Captain, Barbossa,, long, believed, to, be, d...
# 2     [A, cryptic, message, from, Bond’s, past, send...
# 3     [Following, the, death, of, District, Attorney...
# ...

# %%
#we need to hand;e the white spaeces
#sam worthington should become samworthington for reccomender systems
movies_final['genres']=movies_final['genres'].apply(lambda x:[i.replace(" ","") for i in x])
movies_final['keywords']=movies_final['keywords'].apply(lambda x:[i.replace(" ","") for i in x])
movies_final['cast']=movies_final['cast'].apply(lambda x:[i.replace(" ","") for i in x])
movies_final['crew']=movies_final['crew'].apply(lambda x:[i.replace(" ","") for i in x])
# Out:
# <ipython-input-27-70c30b0ad2e5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_final['genres']=movies_final['genres'].apply(lambda x:[i.replace(" ","") for i in x])
# <ipython-input-27-70c30b0ad2e5>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_final['keywords']=movies_final['keywords'].apply(lambda x:[i.replace(" ","") for i in x])
# <ipython-input-27-70c30b0ad2e5>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
movies_final
# Out:
#         id_x                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                                overview  \
# 0     [In, the, 22nd, century,, a, paraplegic, Marin...
# 1     [Captain, Barbossa,, long, believed, to, be, d...
# 2     [A, cryptic, message, from, Bond’s, past, send...
# 3     [Following, the, death, of, District, Attorney...
# ...

# %%
#creating a tags column by combining all relevant information
movies_final['tags']=movies_final['overview']+movies_final['genres']+movies_final['cast']+movies_final['crew']+movies_final['keywords']
# Out:
# <ipython-input-29-3403c868dc0a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_final['tags']=movies_final['overview']+movies_final['genres']+movies_final['cast']+movies_final['crew']+movies_final['keywords']

# %%
movies_final['tags']
# Out:
# 0       [In, the, 22nd, century,, a, paraplegic, Marin...
# 1       [Captain, Barbossa,, long, believed, to, be, d...
# 2       [A, cryptic, message, from, Bond’s, past, send...
# 3       [Following, the, death, of, District, Attorney...
# 4       [John, Carter, is, a, war-weary,, former, mili...
#                               ...
# 4804    [El, Mariachi, just, wants, to, play, his, gui...
# 4805    [A, newlywed, couple's, honeymoon, is, upended...
# 4806    ["Signed,, Sealed,, Delivered", introduces, a,...
# 4807    [When, ambitious, New, York, attorney, Sam, is...
# 4808    [Ever, since, the, second, grade, when, he, fi...
# Name: tags, Length: 4806, dtype: object

# %%
new_df=movies_final[['id_x', 'title', 'tags']]

# %%
#convert list to string for tags
new_df['tags']=new_df['tags'].apply(lambda x:" ".join(x))
# Out:
# <ipython-input-32-1f3224846ab8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags']=new_df['tags'].apply(lambda x:" ".join(x))

# %%
#convert tags to lower case for simplicity

new_df['tags'] =new_df['tags'].apply(lambda x: x.lower())
# Out:
# <ipython-input-33-a5715d435e83>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] =new_df['tags'].apply(lambda x: x.lower())

# %%
import nltk
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
def stem(text):
  y=[]

  for i in text.split():
    y.append(ps.stem(i))
  return " ".join(y) #convert back to string after stemming

# %%
new_df['tags']=new_df['tags'].apply(stem)
# Out:
# <ipython-input-36-402dd7cb6b10>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags']=new_df['tags'].apply(stem)

# %%
from sklearn.feature_extraction.text import CountVectorizer #basically counts the frequency of words in each piece of text

cv=CountVectorizer(max_features=4000, stop_words='english')

# %%
vectors=cv.fit_transform(new_df['tags']).toarray()

# %%
cv.get_feature_names_out()
# Out:
# array(['000', '007', '10', ..., 'zone', 'zoo', 'zooeydeschanel'],
#       dtype=object)

# %%
#there are some words like 'action', 'actions' and similar sow e apply something called stemming where we replace all similar words with one word
# !pip install nltk

# %%
#we have to calculate the distance  between two vectors, lower distance is better
#we are using cosine distance
#euclidean distance fails in higher dimensioins

from sklearn.metrics.pairwise import cosine_similarity

similar=cosine_similarity(vectors) #this shoes the similarity between first movie with every other movies so obviouslt its tarts with one since first movie is absolutely similar with itself

# %%
def recommend(movie):
  movie_index= new_df[new_df['title']==movie].index[0] #here we are trying to search for a movie given by user say 'avatar'
  distances=similar[movie_index] #IF THE MOVIE WE ARE SEARCHING IS AVATAR then we extract its similarity score with all other 4000 words
  movies_list= sorted(list(enumerate(distances)), reverse=True, key=lambda x:x[1])[1:7]
  #OKAY here we need top movies closest to avatar. Before sortinh though we have to assign an index to each score say 1. for first movie, 2. for second
  #otherwise we sort and the index gets lost, so then we sort based on scores while the numbers are still there
  #we sort based on second thing which is value (enumertae creates a key and value kind of this ensures we only arrange the vale\
  #then we extract the top 6 changed this was 5 in origina
  for i in movies_list:
    print(new_df.iloc[i[0]].title) #gives me movies index

# %%
recommend('Batman Begins')
# Out:
# The Dark Knight
# Batman
# Batman
# 10th & Wolf
# Rockaway
# Batman v Superman: Dawn of Justice

# %%
recommend('Newlyweds')
# Out:
# Bad Grandpa
# How to Fall in Love
# The R.M.
# Time Changer
# After Earth
# Whale Rider

# %%
recommend('Avatar')
# Out:
# Aliens vs Predator: Requiem
# Independence Day
# Falcon Rising
# Titan A.E.
# Jupiter Ascending
# Battle: Los Angeles

# %%
import pickle
pickle.dump(new_df.to_dict(), open('movies.pkl', 'wb'))

# %%
pickle.dump(similar, open('similarity.pkl', 'wb') )

# %%
new_df
# Out:
#         id_x                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                                    tags
# 0     in the 22nd century, a parapleg marin is dispa...
# 1     captain barbossa, long believ to be dead, ha c...
# 2     a cryptic messag from bond’ past send him on a...
# 3     follow the death of district attorney harvey d...
# ...
